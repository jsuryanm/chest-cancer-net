# %% [markdown]
# ### Configbox

# %%
import yaml 

yaml_file_path = "test.yaml"

with open(yaml_file_path,"r") as yaml_file:
    data = yaml.safe_load(yaml_file)

print(data)
# Out:
# {'name': 'js', 'Email': 'js@gmail.com'}

# %%
data['name'],data['Email']
# Out:
# ('js', 'js@gmail.com')

# %%
from box import ConfigBox

config_data = ConfigBox(data)
print(config_data.name)
# Out:
# js

# %%
type(config_data.Email)
# Out:
# str

# %%
def get_product(x: int,y: int):
    return x*y

# %%
get_product(2,2)
# Out:
# 4

# %%
get_product(x=2,y='4')
# Out:
# '44'

# %%
from ensure import ensure_annotations 

@ensure_annotations
def get_products(x:int,y:int):
    return x*y

# %%
get_products(2,4)
# Out:
# 8

# %%
get_products(2,'5')
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 get_products(2,'5')
#
# File c:\Users\rsurs\anaconda3\envs\chest\Lib\site-packages\ensure\main.py:833, in WrappedFunction.__call__(self, *args, **kwargs)
#     831     if not isinstance(value, templ):
#     832         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 833         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     835 return self.f(*args, **kwargs)
#
# EnsureError: Argument y of type <class 'str'> to <function get_products at 0x0000026CE2D7EE80> does not match annotation type <class 'int'>

# %% [markdown]
# ### Downloading data from GDrive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/166i44CxICqxH3bmvXpKUNy8ciLqVUeZr/view?usp=drive_link"

# %%
type(url)
# Out:
# str

# %%
url.split("/")
# Out:
# ['https:',
#  '',
#  'drive.google.com',
#  'file',
#  'd',
#  '166i44CxICqxH3bmvXpKUNy8ciLqVUeZr',
#  'view?usp=drive_link']

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '166i44CxICqxH3bmvXpKUNy8ciLqVUeZr'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=166i44CxICqxH3bmvXpKUNy8ciLqVUeZr
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=166i44CxICqxH3bmvXpKUNy8ciLqVUeZr&confirm=t&uuid=d85c2d85-0000-45b7-ba4a-60ca3053201c
# To: c:\Users\rsurs\OneDrive\Documents\chest-cancer-net\research\Chest-CT-Scan-data.zip
# 100%|██████████| 49.0M/49.0M [00:01<00:00, 37.3MB/s]
# 'Chest-CT-Scan-data.zip'
